# %%
#project title
#Explotory data Analysis and matplotlib 
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sys 
print(sys.path)
# Out:
# ['c:\\Users\\willi\\OneDrive\\Desktop\\numpy', 'c:\\Users\\willi\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\willi\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\willi\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\willi\\AppData\\Local\\Programs\\Python\\Python312', '', 'C:\\Users\\willi\\AppData\\Roaming\\Python\\Python312\\site-packages', 'C:\\Users\\willi\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32', 'C:\\Users\\willi\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib', 'C:\\Users\\willi\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin', 'c:\\Users\\willi\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']

# %%
import os 
os.getcwd()
# Out:
# 'c:\\Users\\willi\\OneDrive\\Desktop\\numpy'

# %%
import os 
print(os.listdir())
# Out:
# ['housing_dataset.csv', 'telecom_churn.csv', 'Untitled-1.ipynb', 'youtube.py']

# %%
file_path = r'housing_dataset.csv'

# %%
#install pandas
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
# ...
#    ---------------------------------------- 0.0/229.9 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/229.9 kB 991.0 kB/s eta 0:00:01
#    ---------- ---------------------------- 61.4/229.9 kB 550.5 kB/s eta 0:00:01
#    ---------- ---------------------------- 61.4/229.9 kB 550.5 kB/s eta 0:00:01
#    ---------- ---------------------------- 61.4/229.9 kB 550.5 kB/s eta 0:00:01
#    ------------- ------------------------- 81.9/229.9 kB 306.3 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
data = pd.read_csv(file_path)
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.size#overall size of the csv folder
# Out:
# 206400

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data.sample(n=8)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9071     -118.15     34.71                  35         1503           309.0
# 11751    -121.18     38.80                  18         2541           414.0
# 7121     -118.02     33.91                  34         2518           429.0
# 7410     -118.21     33.95                  38         1889           565.0
# 11746    -121.16     38.75                  27          771           108.0
# 5274     -118.53     34.03                  40         4350           763.0
# 16831    -122.49     37.59                  35         2683           475.0
# 2378     -119.55     36.71                  32         1963           508.0
#
#        population  households  median_income ocean_proximity  \
# 9071          842         300         2.5278          INLAND
# 11751        1276         405         5.1857          INLAND
# 7121         1309         421         4.7861       <1H OCEAN
# ...

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
data.memory_usage()
# Out:
# Index                    132
# longitude             165120
# latitude              165120
# housing_median_age    165120
# total_rooms           165120
# total_bedrooms        165120
# population            165120
# households            165120
# median_income         165120
# ocean_proximity       165120
# median_house_value    165120
# dtype: int64

# %%
data.iloc[4,1:5]
# Out:
# latitude              37.85
# housing_median_age       52
# total_rooms            1627
# total_bedrooms        280.0
# Name: 4, dtype: object

# %%
#analysing the telecom chat
df = pd.read_csv("telecom_churn.csv")
print(df)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
print(df.shape)
# Out:
# (3333, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
# ...

# %%
df.describe(include=["object","bool"])
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3333
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2850

# %%
print(3010/3333)
# Out:
# 0.903090309030903

# %%
df["Churn"].value_counts()
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
print(483/2850)
# Out:
# 0.1694736842105263

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# False    0.855086
# True     0.144914
# Name: proportion, dtype: float64

# %%
#sorting the data frame based on the column
df.sort_values(by="Total day charge",ascending=False)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
# ...    ...             ...        ...                ...             ...
# 1986    WI              70        415                 No              No
# 2753    OH             134        415                 No              No
# 2736    OK             127        510                 No             Yes
# 1397    VT             101        510                 No              No
# 1345    SD              98        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#sorting the data Frame on multiple features
df=pd.read_csv('telecom_churn.csv')
df.sort_values(by=["Churn","Total day charge"],ascending=False).head(30)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
# 975     DE             129        510                 No              No
# 15      NY             161        415                 No              No
# 1679    OK              82        510                 No              No
# 2028    SD              93        510                 No              No
# 197     TX             208        510                 No              No
# 2412    WI              89        415                 No              No
# 2824    OR              81        415                 No              No
# ...

# %%
print(df["Voice mail plan"].unique())
# Out:
# [1 0]

# %%
df['Voice mail plan'] = df['Voice mail plan'].replace({'Yes': 1, 'No': 0})
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_21160\2476630832.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Voice mail plan'] = df['Voice mail plan'].replace({'Yes': 1, 'No': 0})

# %%
df.iloc[1:10]["Voice mail plan"]
# Out:
# 1    Yes
# 2     No
# 3     No
# 4     No
# 5     No
# 6    Yes
# 7     No
# 8     No
# 9    Yes
# Name: Voice mail plan, dtype: object

# %%
# Mapping dictionary
mapping = {"Yes": 1, "No": 0}

# Replace values using the mapping dictionary
df["Voice mail plan"] = df["Voice mail plan"].replace(mapping)

# Convert the column to integer type
df["Voice mail plan"] = df["Voice mail plan"].astype(int)
df.head(20)
# Out:
#    State  Account length  Area code International plan  Voice mail plan  \
# 0     KS             128        415                 No                1
# 1     OH             107        415                 No                1
# 2     NJ             137        415                 No                0
# 3     OH              84        408                Yes                0
# 4     OK              75        415                Yes                0
# 5     AL             118        510                Yes                0
# 6     MA             121        510                 No                1
# 7     MO             147        415                Yes                0
# 8     LA             117        408                 No                0
# 9     WV             141        415                Yes                1
# 10    IN              65        415                 No                0
# 11    RI              74        415                 No                0
# ...

# %%
#map function is mapping the values
mapping = {"Yes": 1, "No": 0}

# Replace values using the mapping dictionary
df["Churn"] = df["Churn"].replace(mapping)

# Convert the column to integer type
df["Churn"] = df["Churn"].astype(int)
df.head(20)
# Out:
#    State  Account length  Area code  International plan  Voice mail plan  \
# 0     KS             128        415               False                1
# 1     OH             107        415               False                1
# 2     NJ             137        415               False                0
# 3     OH              84        408                True                0
# 4     OK              75        415                True                0
# 5     AL             118        510                True                0
# 6     MA             121        510               False                1
# 7     MO             147        415                True                0
# 8     LA             117        408               False                0
# 9     WV             141        415                True                1
# 10    IN              65        415               False                0
# 11    RI              74        415               False                0
# ...

# %%
df["Total day charge"].mean()
# Out:
# 30.562307230723075

# %%
df["Total day calls"].mean()
# Out:
# 100.43564356435644

# %%
df[df['Churn']==1]["Total day charge"].mean()
# Out:
# 35.17592132505176

# %%
df.apply(np.min)
# Out:
# State                        AK
# Account length                1
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           0.0
# Total day calls               0
# Total day charge            0.0
# Total eve minutes           0.0
# Total eve calls               0
# Total eve charge            0.0
# Total night minutes        23.2
# Total night calls            33
# Total night charge         1.04
# Total intl minutes          0.0
# Total intl calls              0
# Total intl charge           0.0
# Customer service calls        0
# Churn                     False
# dtype: object

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                      True
# dtype: object

# %%
pip install seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for matplotlib!=3.6.1,>=3.4 from https://files.pythonhosted.org/packages/50/ce/a6bc93f7a44dd1fd23698698e369e141f4f24e7098d0a5937808afee3f5e/matplotlib-3.8.3-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/8e/ae/a6353db548bff1a592b85ae6bb80275f0a51dc25a0410d059e5b33183e36/contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...

# %%
#creating heatmap
import seaborn as sn
import matplotlib.pyplot as plt
hm = sn.heatmap(data = df.iloc[:, 4:])
plt.show()
